# %% [markdown]
# ## Setting up google colab

# %%
import kagglehub

# Download latest version

path = kagglehub.dataset_download("prachi13/customer-analytics")

print("Path of the files: ", path)
# Out:
# Path of the files:  /kaggle/input/customer-analytics

# %%
import pandas as pd

df_customer_analytics = pd.read_csv("/kaggle/input/customer-analytics/Train.csv")
df_customer_analytics.shape
# Out:
# (10999, 12)

# %% [markdown]
# This dataset has 109999 total data points and has 12 columns of different categories

# %% [markdown]
# ### Let's see how the first 10 data point of the dataset looks like

# %%
df_customer_analytics.head(10)
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
# 5   6               F           Flight                    3                1
# 6   7               D           Flight                    3                4
# 7   8               F           Flight                    4                1
# 8   9               A           Flight                    3                4
# 9  10               B           Flight                    3                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# ...

# %% [markdown]
# ### Let's see how the last 10 data point of the dataset looks like

# %%
df_customer_analytics.tail(10)
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 10989  10990               B             Ship                    5
# 10990  10991               C             Ship                    5
# 10991  10992               F             Ship                    5
# 10992  10993               D             Ship                    5
# 10993  10994               F             Ship                    5
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 10989                1                  218                5
# 10990                4                  219                6
# ...

# %% [markdown]
# ### What are the columns are in the dataset

# %%
df_customer_analytics.columns.to_list()
# Out:
# ['ID',
#  'Warehouse_block',
#  'Mode_of_Shipment',
#  'Customer_care_calls',
#  'Customer_rating',
#  'Cost_of_the_Product',
#  'Prior_purchases',
#  'Product_importance',
#  'Gender',
#  'Discount_offered',
#  'Weight_in_gms',
#  'Reached.on.Time_Y.N']

# %% [markdown]
# ### How to get the basic information

# %%
df_customer_analytics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10999 entries, 0 to 10998
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   10999 non-null  int64
#  1   Warehouse_block      10999 non-null  object
#  2   Mode_of_Shipment     10999 non-null  object
#  3   Customer_care_calls  10999 non-null  int64
#  4   Customer_rating      10999 non-null  int64
#  5   Cost_of_the_Product  10999 non-null  int64
#  6   Prior_purchases      10999 non-null  int64
#  7   Product_importance   10999 non-null  object
#  8   Gender               10999 non-null  object
#  9   Discount_offered     10999 non-null  int64
#  10  Weight_in_gms        10999 non-null  int64
#  11  Reached.on.Time_Y.N  10999 non-null  int64
# dtypes: int64(8), object(4)
# memory usage: 1.0+ MB

# %% [markdown]
# ### Let's see how many Warehouse Blocks are there

# %%
df_customer_analytics['Warehouse_block'].value_counts()
# Out:
# Warehouse_block
# F    3666
# D    1834
# A    1833
# B    1833
# C    1833
# Name: count, dtype: int64

# %% [markdown]
# ### How many unique customer ratings were provided?

# %%
df_customer_analytics['Customer_rating'].unique()
# Out:
# array([2, 5, 3, 1, 4])

# %% [markdown]
# ### Sorting the values according to ID

# %%
df_customer_analytics.sort_values(by = 'ID', ascending = False)
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 10998  10999               D             Ship                    2
# 10997  10998               F             Ship                    5
# 10996  10997               C             Ship                    5
# 10995  10996               B             Ship                    4
# 10994  10995               A             Ship                    4
# ...      ...             ...              ...                  ...
# 4          5               C           Flight                    2
# 3          4               B           Flight                    3
# 2          3               A           Flight                    2
# 1          2               F           Flight                    4
# 0          1               D           Flight                    4
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 10998                5                  155                5
# ...

# %% [markdown]
# ### Grouping elements of Product Importance and Cost of the product

# %%
df_customer_analytics.groupby('Product_importance')['Cost_of_the_Product']

# %% [markdown]
# ### Renaming the elements of the dataset elements

# %%
df_customer_analytics.rename(columns={"Customer ID":"Customer ID New"},inplace=True)

# %%
df_customer_analytics
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0          1               D           Flight                    4
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 3          4               B           Flight                    3
# 4          5               C           Flight                    2
# ...      ...             ...              ...                  ...
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                    2                  177                3
# ...

# %% [markdown]
# ### Adding a random colum named 'temp'

# %%
df_customer_analytics['temp'] = 'infosys names'

# %% [markdown]
# and then dropping off the column

# %%
df_customer_analytics.drop(columns = ['temp'], inplace = True)
df_customer_analytics
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0          1               D           Flight                    4
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 3          4               B           Flight                    3
# 4          5               C           Flight                    2
# ...      ...             ...              ...                  ...
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                    2                  177                3
# ...

# %% [markdown]
# ### How many customer ratings are > 3

# %%
df_customer_analytics[df_customer_analytics['Customer_rating']>3]['Customer_rating'].value_counts()
# Out:
# Customer_rating
# 4    2189
# 5    2171
# Name: count, dtype: int64

# %% [markdown]
# NEXT UP WE HAVE THE LAMBDA FUNCTIONS

# %% [markdown]
# -------
